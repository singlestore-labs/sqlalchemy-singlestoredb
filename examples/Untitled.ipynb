# %%
import ibis

# %%
url = 'singlestoredb://root:@127.0.0.1:9306/ibis_testing'

# %%
conn = ibis.singlestoredb.connect(url)

# %%
tbl = conn.table('datatypes')

# %%
import os
os.environ['SINGLESTOREDB_DEBUG_QUERIES'] = '1'

# %%
tbl.text_obj.like('%b%').execute()
# Out:
# [QUERY] SHOW CREATE TABLE `datatypes` immutabledict({})
# [QUERY] SELECT t0.text_obj LIKE %(param_1)s AS `StringSQLLike(text_obj, '%%b%%')`
# FROM datatypes AS t0 {'param_1': '%b%'}
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     True
# 7     True
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# 22    None
# 23    None
# 24    True
# 25    None
# 26    None
# 27    None
# 28    None
# 29    None
# 30    None
# 31    None
# Name: StringSQLLike(text_obj, '%b%'), dtype: object

# %%
# %load_ext sql

# %%
# %%sql singlestoredb://root:@127.0.0.1:9306/ibis_testing
# CREATE PIPELINE `insurance_customers`
# AS LOAD DATA KAFKA 'pkc-p11xm.us-east-1.aws.confluent.cloud:9092/test_data'
# CONFIG '{\"sasl.username\": \"N35MPTY66EGMV3QN\",\n         \"sasl.mechanism\": \"PLAIN\",\n         \"security.protocol\": \"SASL_SSL\",\n         \"ssl.ca.location\": \"/etc/pki/ca-trust/extracted/pem/tls-ca-bundle.pem\"}'
# CREDENTIALS '{"sasl.password": "Un4im4XGtOPDZsUGQtsRX9t28kB3MCGtOiZX7UYDMjFGwxKNa4DF18QGL9hEgGWv"}'
# BATCH_INTERVAL 20
# ENABLE OUT_OF_ORDER OPTIMIZATION
# DISABLE OFFSETS METADATA GC
# INTO TABLE `insurance_customers`
# FORMAT JSON (`customer` <- %)
# KAFKA KEY (`timestamp` <- %);
# Out:
# (singlestoredb.exceptions.ProgrammingError) 1146: Table 'ibis_testing.insurance_customers' doesn't exist
# [SQL: CREATE PIPELINE `insurance_customers`
# AS LOAD DATA KAFKA 'pkc-p11xm.us-east-1.aws.confluent.cloud:9092/test_data'
# CONFIG '{\"sasl.username\": \"N35MPTY66EGMV3QN\",\n         \"sasl.mechanism\": \"PLAIN\",\n         \"security.protocol\": \"SASL_SSL\",\n         \"ssl.ca.location\": \"/etc/pki/ca-trust/extracted/pem/tls-ca-bundle.pem\"}'
# CREDENTIALS '{"sasl.password": "Un4im4XGtOPDZsUGQtsRX9t28kB3MCGtOiZX7UYDMjFGwxKNa4DF18QGL9hEgGWv"}'
# BATCH_INTERVAL 20
# ENABLE OUT_OF_ORDER OPTIMIZATION
# DISABLE OFFSETS METADATA GC
# INTO TABLE `insurance_customers`
# FORMAT JSON (`customer` <- %)
# KAFKA KEY (`timestamp` <- %);]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# [QUERY] SELECT VERSION()
# [QUERY] SELECT DATABASE() immutabledict({})
# [QUERY] SELECT @@transaction_isolation
# [QUERY] SELECT @@sql_mode immutabledict({})
# ...

# %%
import sqlalchemy as sa
eng = sa.create_engine('singlestoredb://root:@127.0.0.1:9306/ibis_testing')
conn = eng.connect()

# %%
list(conn.exec_driver_sql('select * from datatypes where id = %(id)s', dict(id=1)))
# Out:
# [QUERY] select * from datatypes where id = %(id)s {'id': 1}
# [(1, 2, 69, 19, 100, 89, 20.4617, 44.244302907932685, Decimal('93.000000'), Decimal('64.73000'), Decimal('61'), datetime.date(2001, 1, 31), datetime.timedelta(days=34, seconds=82799), datetime.timedelta(0), datetime.datetime(2001, 1, 31, 23, 3, 14), datetime.datetime(2001, 1, 31, 23, 3, 14), datetime.datetime(2001, 1, 31, 23, 3, 14), datetime.datetime(2001, 1, 31, 23, 3, 14), 'a', '15.922443005958675', 'a long text', 'a medium text', 'a tiny text', 'text', 'text', b'61', 'medium', 'a,c', -84, -84.4149, None, None, None, None, None, None, None)]

# %%
list(conn.exec_driver_sql('select * from datatypes where id = %s', (1,)))
# Out:
# [QUERY] select * from datatypes where id = %s (1,)
# [(1, 2, 69, 19, 100, 89, 20.4617, 44.244302907932685, Decimal('93.000000'), Decimal('64.73000'), Decimal('61'), datetime.date(2001, 1, 31), datetime.timedelta(days=34, seconds=82799), datetime.timedelta(0), datetime.datetime(2001, 1, 31, 23, 3, 14), datetime.datetime(2001, 1, 31, 23, 3, 14), datetime.datetime(2001, 1, 31, 23, 3, 14), datetime.datetime(2001, 1, 31, 23, 3, 14), 'a', '15.922443005958675', 'a long text', 'a medium text', 'a tiny text', 'text', 'text', b'61', 'medium', 'a,c', -84, -84.4149, None, None, None, None, None, None, None)]

# %%
list(conn.execute(sa.text('select * from datatypes where id = :id'), dict(id=1)))
# Out:
# [QUERY] select * from datatypes where id = %(id)s {'id': 1}
# [(1, 2, 69, 19, 100, 89, 20.4617, 44.244302907932685, Decimal('93.000000'), Decimal('64.73000'), Decimal('61'), datetime.date(2001, 1, 31), datetime.timedelta(days=34, seconds=82799), datetime.timedelta(0), datetime.datetime(2001, 1, 31, 23, 3, 14), datetime.datetime(2001, 1, 31, 23, 3, 14), datetime.datetime(2001, 1, 31, 23, 3, 14), datetime.datetime(2001, 1, 31, 23, 3, 14), 'a', '15.922443005958675', 'a long text', 'a medium text', 'a tiny text', 'text', 'text', b'61', 'medium', 'a,c', -84, -84.4149, None, None, None, None, None, None, None)]

# %%
# %%sql singlestoredb://root:@127.0.0.1:9306/ibis_testing
# CREATE PIPELINE `insurance_customers`
# AS LOAD DATA KAFKA 'pkc-p11xm.us-east-1.aws.confluent.cloud:9092/test_data'
# CONFIG '{\"sasl.username\": \"N35MPTY66EGMV3QN\",\n         \"sasl.mechanism\": \"PLAIN\",\n         \"security.protocol\": \"SASL_SSL\",\n         \"ssl.ca.location\": \"/etc/pki/ca-trust/extracted/pem/tls-ca-bundle.pem\"}'
# CREDENTIALS '{"sasl.password": "Un4im4XGtOPDZsUGQtsRX9t28kB3MCGtOiZX7UYDMjFGwxKNa4DF18QGL9hEgGWv"}'
# BATCH_INTERVAL 20
# ENABLE OUT_OF_ORDER OPTIMIZATION
# DISABLE OFFSETS METADATA GC
# INTO TABLE `insurance_customers`
# FORMAT JSON (`customer` <- %)
# KAFKA KEY (`timestamp` <- %);
# Out:
# (singlestoredb.exceptions.ProgrammingError) 1146: Table 'ibis_testing.insurance_customers' doesn't exist
# [SQL: CREATE PIPELINE `insurance_customers`
# AS LOAD DATA KAFKA 'pkc-p11xm.us-east-1.aws.confluent.cloud:9092/test_data'
# CONFIG '{\"sasl.username\": \"N35MPTY66EGMV3QN\",\n         \"sasl.mechanism\": \"PLAIN\",\n         \"security.protocol\": \"SASL_SSL\",\n         \"ssl.ca.location\": \"/etc/pki/ca-trust/extracted/pem/tls-ca-bundle.pem\"}'
# CREDENTIALS '{"sasl.password": "Un4im4XGtOPDZsUGQtsRX9t28kB3MCGtOiZX7UYDMjFGwxKNa4DF18QGL9hEgGWv"}'
# BATCH_INTERVAL 20
# ENABLE OUT_OF_ORDER OPTIMIZATION
# DISABLE OFFSETS METADATA GC
# INTO TABLE `insurance_customers`
# FORMAT JSON (`customer` <- %)
# KAFKA KEY (`timestamp` <- %);]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# [QUERY] CREATE PIPELINE `insurance_customers`
# AS LOAD DATA KAFKA 'pkc-p11xm.us-east-1.aws.confluent.cloud:9092/test_data'
# ...

# %%
import sqlalchemy as sa
eng = sa.create_engine('singlestoredb://root:@127.0.0.1:9306/ibis_testing')
conn = eng.connect()

# %%
list(conn.exec_driver_sql('select 21 % 2, 101 % 2'))
# Out:
# [(1, 1)]

# %%
list(conn.exec_driver_sql('select 21 %% 2, %s %% 2', (101,)))
# Out:
# [(1, 1)]

# %%
list(conn.exec_driver_sql('select 21 %% 2, %(num)s %% 2', dict(num=101)))
# Out:
# [(1, 1)]

# %%
list(conn.execute(sa.text('select 21 % 2, 101 % 2'), dict(foo=100)))
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1965, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1964     if not evt_handled:
# -> 1965         self.dialect.do_execute(
#    1966             cursor, str_statement, effective_parameters, context
#    1967         )
#    1969 if self._has_events or self.engine._has_events:
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:921, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     920 def do_execute(self, cursor, statement, parameters, context=None):
# --> 921     cursor.execute(statement, parameters)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/singlestoredb/mysql/cursors.py:201, in Cursor.execute(self, query, args)
# ...

# %%
list(conn.execute(sa.text('select 21 % 2, 101 % 2')))
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1965, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1964     if not evt_handled:
# -> 1965         self.dialect.do_execute(
#    1966             cursor, str_statement, effective_parameters, context
#    1967         )
#    1969 if self._has_events or self.engine._has_events:
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/sqlalchemy/engine/default.py:921, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     920 def do_execute(self, cursor, statement, parameters, context=None):
# --> 921     cursor.execute(statement, parameters)
#
# File ~/.pyenv/versions/3.11.3/lib/python3.11/site-packages/singlestoredb/mysql/cursors.py:201, in Cursor.execute(self, query, args)
# ...

# %%
list(conn.execute(sa.text('select 21 % 2, :num % 2'), dict(num=101)))
# Out:
# [(1, 1)]

# %%
# %load_ext sql

# %%
# %%sql singlestoredb://root:@127.0.0.1:9306/ibis_testing
# select 21 % 2, 101 % 2
# Out:
# (singlestoredb.exceptions.ProgrammingError) 1064: You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near '% 2, 101 %% 2' at line 1
# [SQL: select 21 %% 2, 101 %% 2]
# (Background on this error at: https://sqlalche.me/e/20/f405)
